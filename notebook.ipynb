# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/bonds_scored.csv')
print(df.shape)
df.head()
# Out:
# (50, 14)
#        bond_id                 issuer rating  coupon_rate  maturity_year  \
# 0  CUSIP-94671    City of Los Angeles     AA        3.143           2050
# 1  CUSIP-87704  City of San Francisco    AAA        3.100           2030
# 2  CUSIP-77726      City of San Diego    AA+        3.144           2050
# 3  CUSIP-35551       City of San Jose    AA+        3.017           2040
# 4  CUSIP-22838     City of Sacramento     AA        3.143           2030
#
#    outstanding_amount       lon      lat           name  risk_score  \
# 0           109000000 -118.2437  34.0522    Los Angeles       0.141
# 1           882000000 -122.4194  37.7749  San Francisco       0.392
# 2            35000000 -117.1611  32.7157      San Diego       0.165
# 3            21000000 -121.8863  37.3382    Santa Clara       0.373
# 4            18000000 -121.4944  38.5816     Sacramento       0.394
#
#    climate_spread_bps  fair_value_yield  mispricing_bps   VaR_Amount
# ...
